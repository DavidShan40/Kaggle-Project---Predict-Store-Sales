# %% [markdown]
# the first argument is RMSPE score for Sales, the second argument is RMSPE score for Customer.

# %%
lm_result <- c(0.0920480092545085, 0.139843998880705)
ridge_result <- c(0.0699129321153788,0.148385416053673)
lasso_result <- c(0.0695911593683118, 0.148203771003941)
random_forest_result <- c(0.0793932200112622, 0.118335807600756)
boosting <- (0.066, 0.1326)
xgboost_result <- c(0.0853, 0.0893)
