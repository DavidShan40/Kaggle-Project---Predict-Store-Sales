# %%
Boost_XGB = read.csv(file = '../input/try-submission-condat/BoostingXGB_0322.csv', header = TRUE)
RF_XGB = read.csv(file = '../input/try-submission-condat/RFXGB_0321.csv', header = TRUE)
XGB = read.csv(file = '../input/try-submission-condat/XGB_0323_nocustomer.csv', header = TRUE)

# %%
outDat = (Boost_XGB + RF_XGB)/4 + XGB/2

# %%
write.csv(outDat, file = 'model_sampling.csv', row.names = FALSE)
